# %% [markdown]
# # Test Notebook for Terraform State Demo
# This is a simple notebook to demonstrate how Terraform state changes when a new resource is deployed.

# %%
# A very simple Python cell
print("Hello from the test notebook!")
